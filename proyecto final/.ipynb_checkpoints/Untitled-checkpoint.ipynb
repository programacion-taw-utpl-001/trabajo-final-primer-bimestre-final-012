# %% [markdown]
# # Proyecto de Visualización de Datos

# %% [markdown]
# ## Guía de Instalación
#
# ### Instalación con pip en Windows
#
# Para la instalación de Jupyter, Bokeh y Pandas en windos tendremos que ir a la direccion en la que se ha instalado Python, por lo general de manera nativa se ubica en
#
# ```cmd
# cd C:\Users\local_user\AppData\Local\Programs\Python\Python36-32
# ```
#
# Seguidamente nos dirigimos hacia la carpeta Scripts que se encuentra dentro del directorio de Instalación de Python
#
# ```cmd
# cd Scripts
# ```
# Una vez dentro podemos instalar los Scripts necesarios para el uso del presente trabajo.
# Cada línea de comando debe ser ejecutada una vez terminada cada instalación de las librerias
#
# ```cmd
# pip3 install jupyterhub
# pip3 install bokeh
# pip3 install pandas
# ```
#
# Para la visualización del proyecto debemos ejecutar lo siguiente
#
# ```cmd
# git clone https://github.com/programacion-taw-utpl-001/trabajo-final-primer-bimestre-final-012.git
# cd trabajo-final-primer-bimestre-final-012
# python -m notebook
# ```
#
# ### Instalación en Linux/Ubuntu
#
# Para iniciar debemos estar seguros de que nuestro sistema esta actualizado, para esto ejecutamos el siguiente comando
#
# ```cmd
# sudo apt-get update
# ```
# Si queremos actualizar nuestro pip ejecutamos el siguiente comando
#
# ```cmd
# pip3 install --upgrade pip
# ```
#
# Una vez asegurados que esta acutalizado podemos instalar las 3 librerias desde el terminal con los comandos
#
# ```cmd
# pip3 install jupyterhub
# pip3 install --upgrade notebook
# pip3 install bokeh
# pip3 install pandas
# ```
# Para abrir el proyecto debemos clonarlo; para visualizarlo debemos ejecutar lo siguiente:
#
# ```cmd
# git clone https://github.com/programacion-taw-utpl-001/trabajo-final-primer-bimestre-final-012.git
# cd trabajo-final-primer-bimestre-final-012
# jupyter notebook
# ```

# %% [markdown]
# ## Marco Teórico
# ### Python
#
# Python fue creado a finales de los años ochenta, por [Guido van Rossum](http://www.maestrosdelweb.com/introspectiva-guido-van-rossum-python/) en el Centro para las Matemáticas y la Informática en los paises bajos.
# El nombre del lenguaje proviene de la adficion de su creador por los humoristas británicos Monty Python.
#
# Python es un lenguaje de programación fácil de aprender, eficiente y con un enfoque a la programación orientada a objetos.
# La facilidad de tipado, y su limpia sintaxis hace de Python un lenguaje para el desarrollo rapido de aplicaciones en diversas áreas y sobre la mayoría de las plataformas.
#
# La filosofía de Python trata en que la sintaxis favorezca a que sea un código legible.
#
# ### JupyterHub
# Es una aplicación web de código abierto que nos permite crear y compartir documentos con un enfoque al modulado estadístico.
#
# ### Pandas
# Es una librería para Python, que nos permite la manipulación de datos y su análisis. Nos ofrece rápidas y flexibles estructuras y operaciones para el manejo de tablas numéricas, haciendolas más fáciles e intuitivas.
#
# ### Bokeh
# Es una libreria interactiva de Python que nos ayuda para presentacion de datos en navegadores. Es elegantem y nos permite crear graficas interactivas de manera sencilla.
# Dentro de su [Guia de Usuario](https://bokeh.pydata.org/en/latest/docs/user_guide.html) podremos encontrar algunos ejemplos de gráficas con las que podemos tomar como ejemplares al querer usar esta librería.

# %% [markdown]
# ## Introducción
#
# Para la realización de este proyecto nos basaremos en los datos estadísticos que extraeremos de la pagina [Ecuado en Cifras](http://www.ecuadorencifras.gob.ec/institucional/home/) sobre el Censo en Ecuador 2010 para su posterior presentación y manejo de datos con las librerías antes mencionadas.

# %% [markdown]
# ## Metodología
# El uso de las librerías anteriormente citadas es indispensable para el desarrollo de este proyecto.
# Lo primero que debemos hacer es leer un archivo ".csv" para ser leído por pandas, para esto usaremos un metodo que se encuentra en pandas llamado **read_csv(nombreFichero,lenguaje_en_uso)** para que se lea y poder albergar la data en una variable que crearemos.

# %%
import pandas as pd

# %% [markdown]
# ```python
# variable= read_csv("nombreFichero.csv",engine='lenguaje_en_uso')
# ```
# Al hacer esto ya tendremos nuestro .csv dentro de una variable para poder usarlo, lo siguiente es que se presenta la data en un "DataFrame" que su funcion es dar la data ordenada y tabulada para una mejor presentación entre filas y columnas.
#
# Otros métodos que seran necesarios durante el trabajo del proyecto son:
#
# * ColumDataSource() Es un metodo muy importante que nos permite el manejo de DataFrame para ser enviados a un metodo figure para que se realice su presentación.
# ```python
# source = ColumnDataSource(data=data)
# ```
#
# * figure() es un método que nos permite realizar figuras para ser presentadas
# ```python
# p = figure(x_range, y_range, plot_height, title,toolbar_location, tools)
# ```
#
# * show() Este método nos permite la presentación de la figura que se la pase como parámetro
# ```python
# show(parametro)
# ```

# %%
# Para leer nuestra tabla utilizaremos una variable y ya que se trata de un archivo cssv utilizaremos el comando pd.read_csv que es pra leeelo
# Nuestro dataset es sobre el ultimo censo en ecuador en 2010
datos=pd.read_csv('dasetecudor-2010 (2).csv', engine='python')
datos
# Out:
#                  Provincia                          Canton  \
# 0                    Azuay  CAMILO PONCE ENRIQUEZ
# 1                    Azuay                             NaN
# 2                    Azuay                             NaN
# 3                    Azuay  CHORDELEG
# 4                    Azuay                             NaN
# 5                    Azuay                             NaN
# 6                    Azuay                             NaN
# 7                    Azuay                             NaN
# 8                    Azuay                             NaN
# 9                    Azuay  CUENCA
# 10                   Azuay                             NaN
# 11                   Azuay                             NaN
# 12                   Azuay                             NaN
# 13                   Azuay                             NaN
# 14                   Azuay                             NaN
# 15                   Azuay                             NaN
# 16                   Azuay                             NaN
# 17                   Azuay                             NaN
# 18                   Azuay                             NaN
# 19                   Azuay                             NaN
# 20                   Azuay                             NaN
# 21                   Azuay                             NaN
# 22                   Azuay                             NaN
# 23                   Azuay                             NaN
# 24                   Azuay                             NaN
# 25                   Azuay                             NaN
# 26                   Azuay                             NaN
# 27                   Azuay                             NaN
# 28                   Azuay                             NaN
# 29                   Azuay                             NaN
# ...                    ...                             ...
# 1244         Santo Domingo                             NaN
# 1245         Santo Domingo                             NaN
# 1246         Santo Domingo                             NaN
# 1247         Santo Domingo                             NaN
# 1248         Santo Domingo                             NaN
# 1249         Santo Domingo                             NaN
# 1250         Santo Domingo                             NaN
# 1251         Santo Domingo                           Total
# 1252           Santa Elena  LIBERTAD
# 1253           Santa Elena                             NaN
# 1254           Santa Elena  SALINAS
# 1255           Santa Elena                             NaN
# 1256           Santa Elena                             NaN
# 1257           Santa Elena                             NaN
# 1258           Santa Elena  SANTA ELENA
# 1259           Santa Elena                             NaN
# 1260           Santa Elena                             NaN
# 1261           Santa Elena                             NaN
# 1262           Santa Elena                             NaN
# 1263           Santa Elena                             NaN
# 1264           Santa Elena                             NaN
# 1265           Santa Elena                             NaN
# 1266           Santa Elena                           Total
# 1267  Zonas No Delimitadas  EL PIEDRERO
# 1268  Zonas No Delimitadas                             NaN
# 1269  Zonas No Delimitadas  LAS GOLONDRINAS
# 1270  Zonas No Delimitadas                             NaN
# 1271  Zonas No Delimitadas  MANGA DEL CURA
# 1272  Zonas No Delimitadas                             NaN
# 1273  Zonas No Delimitadas                           Total
#
#                             Parroquia  Hombre   Mujer   Total
# 0               CAMILO PONCE ENRIQUEZ    9766    7638   17404
# 1                 EL CARMEN DE PIJILI    2445    2149    4594
# 2                               Total   12211    9787   21998
# 3                           CHORDELEG    3241    3546    6787
# 4                            LA UNION     867    1029    1896
# 5               LUIS GALARZA ORELLANA     661     833    1494
# 6                           PRINCIPAL     597     734    1331
# 7                SAN MARTIN DE PUZHIO     455     614    1069
# 8                               Total    5821    6756   12577
# 9                               BAÑOS    7868    8983   16851
# 10                            CHAUCHA     617     680    1297
# 11                     CHECA (JIDCAY)    1182    1559    2741
# 12                         CHIQUINTAD    2251    2575    4826
# 13                             CUENCA  158365  173523  331888
# 14                              CUMBE    2480    3066    5546
# 15                             LLACAO    2487    2855    5342
# 16                          MOLLETURO    3681    3485    7166
# 17                              NULTI    2107    2217    4324
# 18           OCTAVIO CORDERO PALACIOS     983    1288    2271
# 19                             PACCHA    2961    3506    6467
# 20                            QUINGEO    3421    4029    7450
# 21                           RICAURTE    9247   10114   19361
# 22                        SAN JOAQUIN    3522    3933    7455
# 23                          SANTA ANA    2472    2894    5366
# 24                            SAYAUSI    3943    4449    8392
# 25                             SIDCAY    1743    2221    3964
# 26                           SININCAY    7277    8582   15859
# 27                             TARQUI    4833    5657   10490
# 28                               TURI    4177    4787    8964
# 29                              VALLE   11489   12825   24314
# ...                               ...     ...     ...     ...
# 1244                   LUZ DE AMERICA    5690    5191   10881
# 1245                     PUERTO LIMON    4892    4452    9344
# 1246              SAN JACINTO DEL BUA    6134    5584   11718
# 1247           SANTA MARIA DEL TOACHI    2991    2624    5615
# 1248   SANTO DOMINGO DE LOS COLORADOS  150428  155204  305632
# 1249                    VALLE HERMOSO    4880    4455    9335
# 1250                            Total  183058  184955  368013
# 1251                              NaN  183058  184955  368013
# 1252                      LA LIBERTAD   48030   47912   95942
# 1253                            Total   48030   47912   95942
# 1254                        ANCONCITO    6116    5706   11822
# 1255                 JOSE LUIS TAMAYO   11054   11010   22064
# 1256                          SALINAS   18266   16523   34789
# 1257                            Total   35436   33239   68675
# 1258                        ATAHUALPA    1689    1843    3532
# 1259                          CHANDUY    8337    8026   16363
# 1260                         COLONCHE   16158   15164   31322
# 1261                      MANGLARALTO   15200   14312   29512
# 1262                SAN JOSE DE ANCON    3439    3438    6877
# 1263                      SANTA ELENA   26816   26358   53174
# 1264                    SIMON BOLIVAR    1757    1539    3296
# 1265                            Total   73396   70680  144076
# 1266                              NaN  156862  151831  308693
# 1267                      EL PIEDRERO    3305    3019    6324
# 1268                            Total    3305    3019    6324
# 1269                  LAS GOLONDRINAS    2768    2534    5302
# 1270                            Total    2768    2534    5302
# 1271                   MANGA DEL CURA   11083    9675   20758
# 1272                            Total   11083    9675   20758
# 1273                              NaN   17156   15228   32384
#
# [1274 rows x 6 columns]

# %%
# A nuestra variable le ponemos .colums ya que eso nos ayudara a precentar el encabezado de nuestras columnas
datos.columns
# Out:
# Index(['Provincia', 'Canton', ' Parroquia', 'Hombre', 'Mujer', 'Total'], dtype='object')

# %%
# Ahora a nuestro dataset lo meteremos dentro de una tabla para poder manipularla
tabla1 = pd.read_csv('dasetecudor-2010 (2).csv')

# %%
# invocamos a nuestra tabla
type(tabla1)
# Out:
# pandas.core.frame.DataFrame

# %%
# ahora presentaremos los datos mas significativos para nosotros
tabla1[['Provincia','Canton','Hombre', 'Mujer']]
# Out:
#                  Provincia                          Canton  Hombre   Mujer
# 0                    Azuay  CAMILO PONCE ENRIQUEZ             9766    7638
# 1                    Azuay                             NaN    2445    2149
# 2                    Azuay                             NaN   12211    9787
# 3                    Azuay  CHORDELEG                         3241    3546
# 4                    Azuay                             NaN     867    1029
# 5                    Azuay                             NaN     661     833
# 6                    Azuay                             NaN     597     734
# 7                    Azuay                             NaN     455     614
# 8                    Azuay                             NaN    5821    6756
# 9                    Azuay  CUENCA                            7868    8983
# 10                   Azuay                             NaN     617     680
# 11                   Azuay                             NaN    1182    1559
# 12                   Azuay                             NaN    2251    2575
# 13                   Azuay                             NaN  158365  173523
# 14                   Azuay                             NaN    2480    3066
# 15                   Azuay                             NaN    2487    2855
# 16                   Azuay                             NaN    3681    3485
# 17                   Azuay                             NaN    2107    2217
# 18                   Azuay                             NaN     983    1288
# 19                   Azuay                             NaN    2961    3506
# 20                   Azuay                             NaN    3421    4029
# 21                   Azuay                             NaN    9247   10114
# 22                   Azuay                             NaN    3522    3933
# 23                   Azuay                             NaN    2472    2894
# 24                   Azuay                             NaN    3943    4449
# 25                   Azuay                             NaN    1743    2221
# 26                   Azuay                             NaN    7277    8582
# 27                   Azuay                             NaN    4833    5657
# 28                   Azuay                             NaN    4177    4787
# 29                   Azuay                             NaN   11489   12825
# ...                    ...                             ...     ...     ...
# 1244         Santo Domingo                             NaN    5690    5191
# 1245         Santo Domingo                             NaN    4892    4452
# 1246         Santo Domingo                             NaN    6134    5584
# 1247         Santo Domingo                             NaN    2991    2624
# 1248         Santo Domingo                             NaN  150428  155204
# 1249         Santo Domingo                             NaN    4880    4455
# 1250         Santo Domingo                             NaN  183058  184955
# 1251         Santo Domingo                           Total  183058  184955
# 1252           Santa Elena  LIBERTAD                         48030   47912
# 1253           Santa Elena                             NaN   48030   47912
# 1254           Santa Elena  SALINAS                           6116    5706
# 1255           Santa Elena                             NaN   11054   11010
# 1256           Santa Elena                             NaN   18266   16523
# 1257           Santa Elena                             NaN   35436   33239
# 1258           Santa Elena  SANTA ELENA                       1689    1843
# 1259           Santa Elena                             NaN    8337    8026
# 1260           Santa Elena                             NaN   16158   15164
# 1261           Santa Elena                             NaN   15200   14312
# 1262           Santa Elena                             NaN    3439    3438
# 1263           Santa Elena                             NaN   26816   26358
# 1264           Santa Elena                             NaN    1757    1539
# 1265           Santa Elena                             NaN   73396   70680
# 1266           Santa Elena                           Total  156862  151831
# 1267  Zonas No Delimitadas  EL PIEDRERO                       3305    3019
# 1268  Zonas No Delimitadas                             NaN    3305    3019
# 1269  Zonas No Delimitadas  LAS GOLONDRINAS                   2768    2534
# 1270  Zonas No Delimitadas                             NaN    2768    2534
# 1271  Zonas No Delimitadas  MANGA DEL CURA                   11083    9675
# 1272  Zonas No Delimitadas                             NaN   11083    9675
# 1273  Zonas No Delimitadas                           Total   17156   15228
#
# [1274 rows x 4 columns]

# %%
# ya que sabemos que gracias a la tabla podemos presentar un dato especifico presentaremos total que es el que contiene el total de poblacion de cada provincia
tabla1.loc[tabla1.Canton == 'Total']
# Out:
#                  Provincia Canton  Parroquia   Hombre    Mujer    Total
# 90                   Azuay  Total        NaN   337044   375083   712127
# 205                 Carchi  Total        NaN    81155    83369   164524
# 253               Cotopaxi  Total        NaN   198625   210580   409205
# 319             Chimborazo  Total        NaN   219401   239180   458581
# 397                 El Oro  Total        NaN   304362   296297   600659
# 470             Esmeraldas  Total        NaN   271312   262780   534092
# 550                 Guayas  Total        NaN  1815914  1829569  3645483
# 599               Imbabura  Total      Total   193664   204580   398244
# 708                   Loja  Total        NaN   220794   228172   448966
# 749               Los Rios  Total        NaN   398099   380016   778115
# 847                 Manabi  Total      Total   689299   680481  1369780
# 918        Morona Santiago  Total        NaN    74849    73091   147940
# 947                   Napo  Total        NaN    52774    50923   103697
# 973                Pastaza  Total        NaN    42260    41673    83933
# 1042             Pichincha  Total        NaN  1255711  1320576  2576287
# 1105            Tungurahua  Total      Total   244783   259800   504583
# 1150      Zamora Chinchipe  Total        NaN    47452    43924    91376
# 1162             Galápagos  Total        NaN    13021    12103    25124
# 1203             Sucumbíos  Total        NaN    92848    83624   176472
# 1241              Orellana  Total        NaN    72130    64266   136396
# 1251         Santo Domingo  Total        NaN   183058   184955   368013
# 1266           Santa Elena  Total        NaN   156862   151831   308693
# 1273  Zonas No Delimitadas  Total        NaN    17156    15228    32384

# %%
# Ahora llamaremos algunas librerias de bokeh que nos ayudaran a presentar nuestros graficos
from bokeh.io import output_notebook, output_file
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="43858ee1-54d3-41f9-81ec-d2d37bd8b028">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.io import show
from bokeh.plotting import figure

# %%
# con ayuda de .iloc podemos recorrer el indice de cada dato asi podemos llamar solo a los que necesitamos
# en esta ocacion llamaremos solo a las 4 provincias mas pobladas del ecuador en 2010
tabla1. iloc [[ 749 ,  847 ,  550,1042 ],  [0, 1,3,4 ]]
# Out:
#       Provincia Canton   Hombre    Mujer
# 749    Los Rios  Total   398099   380016
# 847      Manabi  Total   689299   680481
# 550      Guayas  Total  1815914  1829569
# 1042  Pichincha  Total  1255711  1320576

# %% [markdown]
# Con los métodos anteriormente mencionados (que son los más importantes para nuestro proyecto) podremos tener como resultados los siguientes gráficos

# %% [markdown]
# Con la siguiente gráfica podemos notar que Guayaquil es el predominante entre las provincias más grandes de nuestro país y que con esto viene a ser la provincia con mayor población en el Ecuador.

# %%
# con ayuda de bokeh podemos obtener varios tipos de graficos
# https://bokeh.pydata.org/en/latest/docs/gallery.html
# En esta ocasion utilizaremos un grafico de barras para presentar la poblacion de hombres y mujeres
from bokeh.core.properties import value
from bokeh.models import ColumnDataSource
from bokeh.transform import dodge

output_file('Maspobladas.html')

provincias = ['guayaquil', 'Pichincha', 'Los rios', 'Manabi']
names = ['Hombres', 'Mujeres']

data = {'capital' : provincias,
        'Hombres'   : [1815914, 1255711, 398099, 689299],
        'Mujeres'   : [1829569, 1320576, 380016, 680481]}

source = ColumnDataSource(data=data)

p = figure(x_range=provincias, y_range=(0, 2000000), plot_height=350, title="Censo de las provincias mas grandes",
           toolbar_location=None, tools="")

p.vbar(x=dodge('capital', -0.25, range=p.x_range), top='Hombres', width=0.2, source=source,
       color="#c9d9d3", legend=value("H"))

p.vbar(x=dodge('capital',  0.0,  range=p.x_range), top='Mujeres', width=0.2, source=source,
       color="#718dbf", legend=value("M"))

p.x_range.range_padding = 0.1
p.xgrid.grid_line_color = None
p.legend.location = "top_left"
p.legend.orientation = "horizontal"

show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="a4aa6195-e9eb-42e1-a49b-1ad37d60b46c"></div>
# </div>

# %%
# con ayuda de .iloc podemos recorrer el indice de cada dato asi podemos llamar solo a los que necesitamos
# en esta ocacion llamaremos solo a las 4 provincias menos pobladas del ecuador en 2010
tabla1. iloc [[ 947 ,  973 ,  1162,1150 ],  [0, 1,3,4 ]]
# Out:
#              Provincia Canton Hombre  Mujer
# 947               Napo  Total  52774  50923
# 973            Pastaza  Total  42260  41673
# 1162         Galápagos  Total  13021  12103
# 1150  Zamora Chinchipe  Total  47452  43924

# %% [markdown]
# En esta gráfica podemos observar que Galápagos es la provincia menos poblada del Ecuador, pero al no tener tanta población da paso a que en épocas de turismo esta provincia tenga mayor cavida para turisticas tanto locales como extranjeros.

# %%
# con ayuda de bokeh podemos obtener varios tipos de graficos
# https://bokeh.pydata.org/en/latest/docs/gallery.html
# En esta ocasion utilizaremos un grafico de barras para presentar la poblacion de hombres y mujeres
from bokeh.core.properties import value
from bokeh.models import ColumnDataSource
from bokeh.transform import dodge

output_file('Menospobladas.html')

provincias = ['Napo', 'Pastaza', 'Galapagos', 'Zamora Chinchipe']
names = ['Hombres', 'Mujeres']

data = {'capital' : provincias,
        'Hombres'   : [52774, 42260, 13021, 47452],
        'Mujeres'   : [50923, 41673, 12103, 43924]}

source = ColumnDataSource(data=data)

p = figure(x_range=provincias, y_range=(0, 80000), plot_height=350, title="Censo de las provincias mas pequeñas",
           toolbar_location=None, tools="")

p.vbar(x=dodge('capital', -0.25, range=p.x_range), top='Hombres', width=0.2, source=source,
       color="#00FFFF", legend=value("H"))

p.vbar(x=dodge('capital',  0.0,  range=p.x_range), top='Mujeres', width=0.2, source=source,
       color="#E5D512", legend=value("M"))

p.x_range.range_padding = 0.1
p.xgrid.grid_line_color = None
p.legend.location = "top_left"
p.legend.orientation = "horizontal"

show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="319b2674-47a6-4ed9-8091-23dd426790b7"></div>
# </div>

# %%
# con ayuda de .iloc podemos recorrer el indice de cada dato asi podemos llamar solo a los que necesitamos
# en esta ocacion llamaremos  a todas provincias de la region costa  del ecuador en 2010
tabla1. iloc [[ 397 ,  470 ,  550,749,847,1251,1266 ],  [0, 1,3,4]]
# Out:
#           Provincia Canton   Hombre    Mujer
# 397          El Oro  Total   304362   296297
# 470      Esmeraldas  Total   271312   262780
# 550          Guayas  Total  1815914  1829569
# 749        Los Rios  Total   398099   380016
# 847          Manabi  Total   689299   680481
# 1251  Santo Domingo  Total   183058   184955
# 1266    Santa Elena  Total   156862   151831

# %% [markdown]
# En esta gráfica podemos observar que Guayaquil predomina sobre todas las demás provincias con con una diferencia demasiado notable en cuanto población y que Santa Elena es la menos poblada y con mayor equilibrio poblacional tanto en hombres como mujeres.

# %%
# con ayuda de bokeh podemos obtener varios tipos de graficos
# https://bokeh.pydata.org/en/latest/docs/gallery.html
# En esta ocasion utilizaremos un grafico de barras para presentar la poblacion de hombres y mujeres
from bokeh.core.properties import value
from bokeh.io import show, output_file
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure

output_file("Provincias de la Costa.html")

fruits = ['El Oro', 'Esmeraldas', 'Guayas', 'Los Rios', 'Manabi', 'Santo Domingo', 'Santa Elena']
years = ["Hombres", "Mujeres"]
colors = ["green", "yellow"]

data = {'fruits' : fruits,
        'Hombres'   : [304362, 271312, 1815914, 398099, 689299, 183058,156862],
        'Mujeres'   : [296297, 262780, 1829569, 380016, 680481, 184955,151831],}

source = ColumnDataSource(data=data)

p = figure(x_range=fruits, plot_height=650, title="Censo de las provinias de la costa del 2010 ",
           toolbar_location=None, tools="")

p.vbar_stack(years, x='fruits', width=0.9, color=colors, source=source,
             legend=[value(x) for x in years])

p.y_range.start = 0
p.x_range.range_padding = 0.1
p.xgrid.grid_line_color = None
p.axis.minor_tick_line_color = None
p.outline_line_color = None
p.legend.location = "top_right"
p.legend.orientation = "horizontal"

show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="3fc6a32e-69cf-49e0-839c-24e33d0a0aa1"></div>
# </div>

# %%
# con ayuda de .iloc podemos recorrer el indice de cada dato asi podemos llamar solo a los que necesitamos
# en esta ocacion llamaremos  a todas provincias de la region sierra  del ecuador en 2010
tabla1. iloc [[ 90,124 ,165,  205 ,  253,319,599,708,1042,1105 ],  [0, 1,3,4 ]]
# Out:
#        Provincia  Canton   Hombre    Mujer
# 90         Azuay   Total   337044   375083
# 124      Bolivar   Total    89875    93766
# 165        Cañar   Total   105235   119949
# 205       Carchi   Total    81155    83369
# 253     Cotopaxi   Total   198625   210580
# 319   Chimborazo   Total   219401   239180
# 599     Imbabura   Total   193664   204580
# 708         Loja   Total   220794   228172
# 1042   Pichincha   Total  1255711  1320576
# 1105  Tungurahua   Total   244783   259800

# %% [markdown]
# Como podemos observar la población censada en Ecuador el 2010 es mayoritaria en Pichincha al contrario que Carchi que vendría a ser la de menor población; también podemos observar que hay mayor cantidad de mujeres que hombres en Pichincha y un poco más equilibrado Carchi con su población.

# %%
# con ayuda de bokeh podemos obtener varios tipos de graficos
# https://bokeh.pydata.org/en/latest/docs/gallery.html
# En esta ocasion utilizaremos un grafico de barras horizontales para presentar la poblacion de hombres y mujeres
from bokeh.io import output_file, show
from bokeh.models import ColumnDataSource
from bokeh.palettes import GnBu3, OrRd3
from bokeh.plotting import figure

output_file("Censo del 2010 de la Sierra.html")

fruits = ['Azuay', 'Bolivar', 'Cañar', 'Carchi', 'Cotopaxi', 'Chimborazo', 'Imbabura', 'Loja', 'Pichincha', 'Tungurahua']
years = ["Hombres", "Mujeres"]
colors = ["red", "blue"]

exports = {'fruits' : fruits,
           'Hombres'   : [337044, 89875,105235, 81155, 198625, 219401,193664,220794,1255711,244783],
           'Mujeres'   : [375083, 93766, 119949, 83369, 210580, 239180,204580,228172,1320576,259800]}

p = figure(y_range=fruits, plot_height=350, x_range=(0, 2800000), title="Poblacion del 2010 de la Sierra ",
           toolbar_location=None)

p.hbar_stack(years, y='fruits', height=0.9, color=colors, source=ColumnDataSource(exports),
             legend=[value(x)  for x in years])


p.y_range.range_padding = 0.1
p.ygrid.grid_line_color = None
p.legend.location = "bottom_right"
p.axis.minor_tick_line_color = None
p.outline_line_color = None

show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="844ead95-a7db-43ba-8288-9e614ec04107"></div>
# </div>

# %%
# con ayuda de .iloc podemos recorrer el indice de cada dato asi podemos llamar solo a los que necesitamos
# en esta ocacion llamaremos  a todas provincias de la region del oriente  del ecuador en 2010
tabla1. iloc [[ 918 ,  947,973,1150,1203 ,1241],  [0, 1,3,4 ]]
# Out:
#              Provincia Canton Hombre  Mujer
# 918    Morona Santiago  Total  74849  73091
# 947               Napo  Total  52774  50923
# 973            Pastaza  Total  42260  41673
# 1150  Zamora Chinchipe  Total  47452  43924
# 1203         Sucumbíos  Total  92848  83624
# 1241          Orellana  Total  72130  64266

# %% [markdown]
# Como podemos apreciar en el Oriente la provincia de mayor población es Sucumbios y de manera casi igualada esta Morona Santiago y Orellana.

# %%
# con ayuda de bokeh podemos obtener varios tipos de graficos
# https://bokeh.pydata.org/en/latest/docs/gallery.html
# En esta ocasion utilizaremos un grafico de barras verticales para presentar la poblacion de hombres y mujeres
from bokeh.io import show, output_file
from bokeh.models import FactorRange
from bokeh.plotting import figure

output_file("provincias del oriente.html")

factors = [
    ("Morona Santiago", "Hombre"), ("Morona Santiago", "Mujer"),
    ("Napo", "Hombre"), ("Napo", "Mujer"),
    ("Pastaza", "Hombre"), ("Pastaza", "Mujer"),
    ("Zamora Chinchipe", "Hombre"), ("Zamora Chinchipe", "Mujer"),
    ("Sucumbíos", "Hombre"), ("Sucumbíos", "Mujer"),
    ("Orellana", "Hombre"), ("Orellana", "Mujer"),

]

p = figure(x_range=FactorRange(*factors), plot_height=350,
           toolbar_location=None, tools="",title="Poblacion del 2010 del oriente ")


x = [ 74849, 73091, 52774, 50923, 42260, 41673, 47452, 43924, 92848, 83624, 72130, 64266 ]
p.vbar(x=factors, top=x, width=0.9, alpha=0.5)


p.y_range.start = 0
p.x_range.range_padding = 0.1
p.xaxis.major_label_orientation = 1
p.xgrid.grid_line_color = None

show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="b13a4437-d269-4770-8f1b-1ba743020ee4"></div>
# </div>

# %%
# con ayuda de .iloc podemos recorrer el indice de cada dato asi podemos llamar solo a los que necesitamos
# en esta ocacion llamaremos  a todas provincias del ecuador en 2010 con el total de su poblacion
tabla1. iloc [[ 90,124,165 , 205, 253, 319, 397, 470,550,599,708,749,847,918,947, 973 ,1042,1105,1150,1162,1203,1241,1251,1266,1273 ],  [0, 5]]
# Out:
#                  Provincia    Total
# 90                   Azuay   712127
# 124                Bolivar   183641
# 165                  Cañar   225184
# 205                 Carchi   164524
# 253               Cotopaxi   409205
# 319             Chimborazo   458581
# 397                 El Oro   600659
# 470             Esmeraldas   534092
# 550                 Guayas  3645483
# 599               Imbabura   398244
# 708                   Loja   448966
# 749               Los Rios   778115
# 847                 Manabi  1369780
# 918        Morona Santiago   147940
# 947                   Napo   103697
# 973                Pastaza    83933
# 1042             Pichincha  2576287
# 1105            Tungurahua   504583
# 1150      Zamora Chinchipe    91376
# 1162             Galápagos    25124
# 1203             Sucumbíos   176472
# 1241              Orellana   136396
# 1251         Santo Domingo   368013
# 1266           Santa Elena   308693
# 1273  Zonas No Delimitadas    32384

# %% [markdown]
# La población total de Ecuador mayor poiblacion en provincias grandes en comparación de las más pequeñas y en relación de las del Oriente.

# %%
from bokeh.io import  show, output_file

# %%
# con ayuda de bokeh podemos obtener varios tipos de graficos
# https://bokeh.pydata.org/en/latest/docs/gallery.html
# En esta ocasion utilizaremos un grafico de lineal para presentar la poblacion total de las provincias 
# y ver que provincia tiene mayor poblacion
from bokeh.layouts import row
from bokeh.plotting import figure, show, output_file

factors = ['Azuay','Bolivar','Cañar' ,'Carchi', 'Cotopaxi', 'Chimborazo', 'El Oro', 'Esmeraldas','Guayas', 'Imbabura', 'Loja', 'Los Rios', 'Manabi','Morona Santiago', 'Napo', 'Pastaza', 'Pichincha', 'Tungurahua','Zamora Chinchipe', 'Galápagos', 'Sucumbíos', 'Orellana', 'Santo Domingo', 'Santa Elena', 'Zonas No Delimitadas']
x =  [712127,183641,225184, 164524, 409205, 458581, 600659, 534092,3645483, 398244, 448966, 778115, 1369780, 147940, 103697, 83933, 2576287,504583, 91376, 25124, 176472, 136396, 368013, 308693, 32384]

dot = figure(title="Total de poblacion por provincia", tools="", toolbar_location=None,
            y_range=factors, x_range=[0,3900000])

dot.segment(0, factors, x, factors, line_width=2, line_color="black", )
dot.circle(x, factors, size=15, fill_color="orange", line_color="green", line_width=5, )


output_file("Total de Poblacion por Provincia.html", title="categorical.py example")

show(row(dot, sizing_mode="scale_width"))  # open a browser
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="856c1a96-9265-47ae-8661-82600abf0a7f"></div>
# </div>

# %%
# Ahora presentaremos un grafico tipo pastel con ayuda de matptlib , en el reflejaremos el total de poblacion por region
from matplotlib import pyplot

# %% [markdown]
# Para finalizar hemos recogido el total de la poblacion para una gráfica en pastel sobre los regiones del Ecuador Costa(juto a Galápagos), Sierra y Oriente.

# %%
# con ayuda de matptlib podemos obtener varios tipos de graficos
#https://matplotlib.org/
# En esta ocasion utilizaremos un grafico de tipo pastel para presentar el total de poblacion por region
# y ver que region tiene mayor poblacion
lenguajes=('Costa','Sierra','Oriente')
slices=(7604835,6081342,739814)
colores=('red','blue','green')
pyplot.pie(slices,shadow=True,labels=lenguajes, colors=colores,autopct=('%1.1f%%'))
# con ayuda del comando autoct podemos calcular el porcenteje y presentarlo
pyplot.title('Censo total por regiones del Ecuador',bbox={"facecolor":"1.8", "pad":5})
pyplot.savefig('Poblacion total por region.png')



pyplot.show()

# %% [markdown]
# ## Resultados
#  * Los datos usados en este proyecto son realizados con datos desactualizados ya que son del año 2010
#  * Las provincias de mayor población son Pichincha y Guayaquil
#  * Las provincias de menor población son Galápagos y Zamora Chinchipe

# %% [markdown]
# ## Conclusión
# Para finalizar, la población del Ecuador es muy diversa e independiente de las provincias, pueden ser atractivos turisticos de gran potencial pero aun asi no es razon para ser más o menos poblada.
#
# La población en Ecuador difiere entre cada año y esto puede producir diversos factores como analfabetismo por no tener familias con recursos suficientes, desempleo, etc.

# %% [markdown]
# ## Bibliografía
#    *  http://docs.python.org.ar/tutorial/3/real-index.html
#    *  https://www.coursera.org/learn/aprendiendo-programar-python
#    *  https://es.wikipedia.org/wiki/Python
#    *  https://bokeh.pydata.org/en/latest/
#    *  http://www.maestrosdelweb.com/introspectiva-guido-van-rossum-python/
#    *  https://bokeh.pydata.org/en/latest/docs/user_guide.html
#    *  https://github.com/bokeh/bokeh
#    *  http://jupyter.org/
#    *  http://jupyterhub.readthedocs.io/en/latest/quickstart.html
#    *  https://github.com/jupyterhub/jupyterhub
#    *  https://en.wikipedia.org/wiki/Pandas_(software)
#    *  https://pandas.pydata.org/pandas-docs/stable/
#    *  https://pandas.pydata.org/

# %% [markdown]
# ## Anexos
#    * Imagenés(png):
# https://github.com/programacion-taw-utpl-001/trabajo-final-primer-bimestre-final-012/tree/master/Anexos
