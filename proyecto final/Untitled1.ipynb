# %%
import pandas as pd

# %%
datos=pd.read_csv('dasetecudor-2010 (1).csv', engine='python')
datos
# Out:
#                  Provincia                          Canton  \
# 0                    Azuay  CAMILO PONCE ENRIQUEZ
# 1                      NaN                             NaN
# 2                      NaN                             NaN
# 3                      NaN  CHORDELEG
# 4                      NaN                             NaN
# 5                      NaN                             NaN
# 6                      NaN                             NaN
# 7                      NaN                             NaN
# 8                      NaN                             NaN
# 9                      NaN  CUENCA
# 10                     NaN                             NaN
# 11                     NaN                             NaN
# 12                     NaN                             NaN
# 13                     NaN                             NaN
# 14                     NaN                             NaN
# 15                     NaN                             NaN
# 16                     NaN                             NaN
# 17                     NaN                             NaN
# 18                     NaN                             NaN
# 19                     NaN                             NaN
# 20                     NaN                             NaN
# 21                     NaN                             NaN
# 22                     NaN                             NaN
# 23                     NaN                             NaN
# 24                     NaN                             NaN
# 25                     NaN                             NaN
# 26                     NaN                             NaN
# 27                     NaN                             NaN
# 28                     NaN                             NaN
# 29                     NaN                             NaN
# ...                    ...                             ...
# 1244                   NaN                             NaN
# 1245                   NaN                             NaN
# 1246                   NaN                             NaN
# 1247                   NaN                             NaN
# 1248                   NaN                             NaN
# 1249                   NaN                             NaN
# 1250                   NaN                             NaN
# 1251                   NaN                           Total
# 1252           Santa Elena  LIBERTAD
# 1253                   NaN                             NaN
# 1254                   NaN  SALINAS
# 1255                   NaN                             NaN
# 1256                   NaN                             NaN
# 1257                   NaN                             NaN
# 1258                   NaN  SANTA ELENA
# 1259                   NaN                             NaN
# 1260                   NaN                             NaN
# 1261                   NaN                             NaN
# 1262                   NaN                             NaN
# 1263                   NaN                             NaN
# 1264                   NaN                             NaN
# 1265                   NaN                             NaN
# 1266                   NaN                           Total
# 1267  Zonas No Delimitadas  EL PIEDRERO
# 1268                   NaN                             NaN
# 1269                   NaN  LAS GOLONDRINAS
# 1270                   NaN                             NaN
# 1271                   NaN  MANGA DEL CURA
# 1272                   NaN                             NaN
# 1273                   NaN                           Total
#
#                             Parroquia  Hombre   Mujer   Total
# 0               CAMILO PONCE ENRIQUEZ    9766    7638   17404
# 1                 EL CARMEN DE PIJILI    2445    2149    4594
# 2                               Total   12211    9787   21998
# 3                           CHORDELEG    3241    3546    6787
# 4                            LA UNION     867    1029    1896
# 5               LUIS GALARZA ORELLANA     661     833    1494
# 6                           PRINCIPAL     597     734    1331
# 7                SAN MARTIN DE PUZHIO     455     614    1069
# 8                               Total    5821    6756   12577
# 9                              BAÃ‘OS    7868    8983   16851
# 10                            CHAUCHA     617     680    1297
# 11                     CHECA (JIDCAY)    1182    1559    2741
# 12                         CHIQUINTAD    2251    2575    4826
# 13                             CUENCA  158365  173523  331888
# 14                              CUMBE    2480    3066    5546
# 15                             LLACAO    2487    2855    5342
# 16                          MOLLETURO    3681    3485    7166
# 17                              NULTI    2107    2217    4324
# 18           OCTAVIO CORDERO PALACIOS     983    1288    2271
# 19                             PACCHA    2961    3506    6467
# 20                            QUINGEO    3421    4029    7450
# 21                           RICAURTE    9247   10114   19361
# 22                        SAN JOAQUIN    3522    3933    7455
# 23                          SANTA ANA    2472    2894    5366
# 24                            SAYAUSI    3943    4449    8392
# 25                             SIDCAY    1743    2221    3964
# 26                           SININCAY    7277    8582   15859
# 27                             TARQUI    4833    5657   10490
# 28                               TURI    4177    4787    8964
# 29                              VALLE   11489   12825   24314
# ...                               ...     ...     ...     ...
# 1244                   LUZ DE AMERICA    5690    5191   10881
# 1245                     PUERTO LIMON    4892    4452    9344
# 1246              SAN JACINTO DEL BUA    6134    5584   11718
# 1247           SANTA MARIA DEL TOACHI    2991    2624    5615
# 1248   SANTO DOMINGO DE LOS COLORADOS  150428  155204  305632
# 1249                    VALLE HERMOSO    4880    4455    9335
# 1250                            Total  183058  184955  368013
# 1251                              NaN  183058  184955  368013
# 1252                      LA LIBERTAD   48030   47912   95942
# 1253                            Total   48030   47912   95942
# 1254                        ANCONCITO    6116    5706   11822
# 1255                 JOSE LUIS TAMAYO   11054   11010   22064
# 1256                          SALINAS   18266   16523   34789
# 1257                            Total   35436   33239   68675
# 1258                        ATAHUALPA    1689    1843    3532
# 1259                          CHANDUY    8337    8026   16363
# 1260                         COLONCHE   16158   15164   31322
# 1261                      MANGLARALTO   15200   14312   29512
# 1262                SAN JOSE DE ANCON    3439    3438    6877
# 1263                      SANTA ELENA   26816   26358   53174
# 1264                    SIMON BOLIVAR    1757    1539    3296
# 1265                            Total   73396   70680  144076
# 1266                              NaN  156862  151831  308693
# 1267                      EL PIEDRERO    3305    3019    6324
# 1268                            Total    3305    3019    6324
# 1269                  LAS GOLONDRINAS    2768    2534    5302
# 1270                            Total    2768    2534    5302
# 1271                   MANGA DEL CURA   11083    9675   20758
# 1272                            Total   11083    9675   20758
# 1273                              NaN   17156   15228   32384
#
# [1274 rows x 6 columns]

# %%
datos.columns
# Out:
# Index(['Provincia', 'Canton', ' Parroquia', 'Hombre', 'Mujer', 'Total'], dtype='object')

# %%
tabla1 = pd.read_csv('dasetecudor-2010 (1).csv')

# %%
type(tabla1)
# Out:
# pandas.core.frame.DataFrame

# %%
tabla1[['Provincia','Canton','Hombre', 'Mujer']]
# Out:
#                  Provincia                          Canton  Hombre   Mujer
# 0                    Azuay  CAMILO PONCE ENRIQUEZ             9766    7638
# 1                      NaN                             NaN    2445    2149
# 2                      NaN                             NaN   12211    9787
# 3                      NaN  CHORDELEG                         3241    3546
# 4                      NaN                             NaN     867    1029
# 5                      NaN                             NaN     661     833
# 6                      NaN                             NaN     597     734
# 7                      NaN                             NaN     455     614
# 8                      NaN                             NaN    5821    6756
# 9                      NaN  CUENCA                            7868    8983
# 10                     NaN                             NaN     617     680
# 11                     NaN                             NaN    1182    1559
# 12                     NaN                             NaN    2251    2575
# 13                     NaN                             NaN  158365  173523
# 14                     NaN                             NaN    2480    3066
# 15                     NaN                             NaN    2487    2855
# 16                     NaN                             NaN    3681    3485
# 17                     NaN                             NaN    2107    2217
# 18                     NaN                             NaN     983    1288
# 19                     NaN                             NaN    2961    3506
# 20                     NaN                             NaN    3421    4029
# 21                     NaN                             NaN    9247   10114
# 22                     NaN                             NaN    3522    3933
# 23                     NaN                             NaN    2472    2894
# 24                     NaN                             NaN    3943    4449
# 25                     NaN                             NaN    1743    2221
# 26                     NaN                             NaN    7277    8582
# 27                     NaN                             NaN    4833    5657
# 28                     NaN                             NaN    4177    4787
# 29                     NaN                             NaN   11489   12825
# ...                    ...                             ...     ...     ...
# 1244                   NaN                             NaN    5690    5191
# 1245                   NaN                             NaN    4892    4452
# 1246                   NaN                             NaN    6134    5584
# 1247                   NaN                             NaN    2991    2624
# 1248                   NaN                             NaN  150428  155204
# 1249                   NaN                             NaN    4880    4455
# 1250                   NaN                             NaN  183058  184955
# 1251                   NaN                           Total  183058  184955
# 1252           Santa Elena  LIBERTAD                         48030   47912
# 1253                   NaN                             NaN   48030   47912
# 1254                   NaN  SALINAS                           6116    5706
# 1255                   NaN                             NaN   11054   11010
# 1256                   NaN                             NaN   18266   16523
# 1257                   NaN                             NaN   35436   33239
# 1258                   NaN  SANTA ELENA                       1689    1843
# 1259                   NaN                             NaN    8337    8026
# 1260                   NaN                             NaN   16158   15164
# 1261                   NaN                             NaN   15200   14312
# 1262                   NaN                             NaN    3439    3438
# 1263                   NaN                             NaN   26816   26358
# 1264                   NaN                             NaN    1757    1539
# 1265                   NaN                             NaN   73396   70680
# 1266                   NaN                           Total  156862  151831
# 1267  Zonas No Delimitadas  EL PIEDRERO                       3305    3019
# 1268                   NaN                             NaN    3305    3019
# 1269                   NaN  LAS GOLONDRINAS                   2768    2534
# 1270                   NaN                             NaN    2768    2534
# 1271                   NaN  MANGA DEL CURA                   11083    9675
# 1272                   NaN                             NaN   11083    9675
# 1273                   NaN                           Total   17156   15228
#
# [1274 rows x 4 columns]

# %%
# A la vez que podemso buscar un dato en especifico
tabla1.loc[tabla1.Canton=='Total',
          tabla1.Provincia=='Azuay']
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-99-f3674f76c4c0> in <module>()
#       1 # A la vez que podemso buscar un dato en especifico
#       2 tabla1.loc[tabla1.Canton=='Total',
# ----> 3           tabla1.Provincia=='Azuay']
#
# c:\users\lenovo\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1365             except (KeyError, IndexError):
#    1366                 pass
# -> 1367             return self._getitem_tuple(key)
#    1368         else:
#    1369             # we by definition only have the 0th axis
#
# c:\users\lenovo\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     876                 continue
#     877
# --> 878             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     879
#     880         return retval
#
# c:\users\lenovo\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1581             return self._get_slice_axis(key, axis=axis)
#    1582         elif is_bool_indexer(key):
# -> 1583             return self._getbool_axis(key, axis=axis)
#    1584         elif is_list_like_indexer(key):
#    1585
#
# c:\users\lenovo\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\indexing.py in _getbool_axis(self, key, axis)
#    1386             axis = self.axis or 0
#    1387         labels = self.obj._get_axis(axis)
# -> 1388         key = check_bool_indexer(labels, key)
#    1389         inds, = key.nonzero()
#    1390         try:
#
# c:\users\lenovo\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\indexing.py in check_bool_indexer(ax, key)
#    2021         mask = isna(result._values)
#    2022         if mask.any():
# -> 2023             raise IndexingError('Unalignable boolean Series provided as '
#    2024                                 'indexer (index of the boolean Series and of '
#    2025                                 'the indexed object do not match')
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match

# %%
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="07fa25a5-ee10-4a3b-bcc1-4169f354fa37">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.io import show
from bokeh.plotting import figure

# %%
from bokeh.core.properties import value
from bokeh.models import ColumnDataSource
from bokeh.transform import dodge

output_file('IncidenciaT.html')

provincias = ['guayaquil', 'Pichincha', 'Los rios', 'Manabi']
names = ['Hombres', 'Mujeres']

data = {'capital' : provincias,
        'Hombres'   : [1815914, 1255711, 398099, 689299],
        'Mujeres'   : [1829569, 1320576, 380016, 680481]}

source = ColumnDataSource(data=data)

p = figure(x_range=provincias, y_range=(0, 2000000), plot_height=350, title="Censo de las provincias mas grandes",
           toolbar_location=None, tools="")

p.vbar(x=dodge('capital', -0.25, range=p.x_range), top='Hombres', width=0.2, source=source,
       color="#c9d9d3", legend=value("H"))

p.vbar(x=dodge('capital',  0.0,  range=p.x_range), top='Mujeres', width=0.2, source=source,
       color="#718dbf", legend=value("M"))

p.x_range.range_padding = 0.1
p.xgrid.grid_line_color = None
p.legend.location = "top_left"
p.legend.orientation = "horizontal"

show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="026422dc-3ba9-4eab-89fb-7cc160e15983"></div>
# </div>
# ERROR:c:\users\lenovo\appdata\local\programs\python\python36-32\lib\site-packages\bokeh\core\validation\check.py:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: anios [renderer: GlyphRenderer(id='20f58654-1d94-4437-919b-2f975a10d3a6', ...)]
# ERROR:c:\users\lenovo\appdata\local\programs\python\python36-32\lib\site-packages\bokeh\core\validation\check.py:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: anios [renderer: GlyphRenderer(id='63bfbf62-f832-4e1d-98a0-8c54b6785421', ...)]
# ERROR:c:\users\lenovo\appdata\local\programs\python\python36-32\lib\site-packages\bokeh\core\validation\check.py:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: anios [renderer: GlyphRenderer(id='bd23a6b2-858d-4329-aaf2-3f7035268bc7', ...)]
# ERROR:c:\users\lenovo\appdata\local\programs\python\python36-32\lib\site-packages\bokeh\core\validation\check.py:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: Nacional [renderer: GlyphRenderer(id='05723927-062a-4214-b20f-4fec3f268f08', ...)]
# ERROR:c:\users\lenovo\appdata\local\programs\python\python36-32\lib\site-packages\bokeh\core\validation\check.py:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: Rural [renderer: GlyphRenderer(id='71941ea1-7105-4a94-b840-225e825611b8', ...)]
# ERROR:c:\users\lenovo\appdata\local\programs\python\python36-32\lib\site-packages\bokeh\core\validation\check.py:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: Urbana [renderer: GlyphRenderer(id='5ace7d2f-47ac-429c-adfb-1307116cd68b', ...)]
# ERROR:c:\users\lenovo\appdata\local\programs\python\python36-32\lib\site-packages\bokeh\core\validation\check.py:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: anios [renderer: GlyphRenderer(id='1cbb8bc8-0d8e-4a82-b431-38bb7c727615', ...)]
# ERROR:c:\users\lenovo\appdata\local\programs\python\python36-32\lib\site-packages\bokeh\core\validation\check.py:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: anios [renderer: GlyphRenderer(id='6bcfe406-7820-45b2-8348-e00e6f51f55f', ...)]
# ERROR:c:\users\lenovo\appdata\local\programs\python\python36-32\lib\site-packages\bokeh\core\validation\check.py:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: anios [renderer: GlyphRenderer(id='8937308d-d86f-4546-81d0-e33151cb9285', ...)]
