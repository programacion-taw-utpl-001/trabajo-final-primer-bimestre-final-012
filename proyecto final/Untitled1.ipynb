# %%
import pandas as pd

# %%
datos=pd.read_csv('dasetecudor-2010_1.csv', engine='python')
datos
# Out:
#                  Provincia               Nombre del Canton  \
# 0                    Azuay  CAMILO PONCE ENRIQUEZ
# 1                      NaN                             NaN
# 2                      NaN                             NaN
# 3                      NaN  CHORDELEG
# 4                      NaN                             NaN
# 5                      NaN                             NaN
# 6                      NaN                             NaN
# 7                      NaN                             NaN
# 8                      NaN                             NaN
# 9                      NaN  CUENCA
# 10                     NaN                             NaN
# 11                     NaN                             NaN
# 12                     NaN                             NaN
# 13                     NaN                             NaN
# 14                     NaN                             NaN
# 15                     NaN                             NaN
# ...

# %%
datos.columns
# Out:
# Index(['Provincia', 'Nombre del Canton', 'Nombre de la Parroquia', 'Hombre',
#        'Mujer', 'Total'],
#       dtype='object')

# %%
tabla1 = pd.read_csv('dasetecudor-2010_1.csv')

# %%
type(tabla1)
# Out:
# pandas.core.frame.DataFrame

# %%
tabla1[['Provincia','Nombre de la Parroquia', 'Hombre', 'Mujer','Total']]
# Out:
#                  Provincia           Nombre de la Parroquia  Hombre   Mujer  \
# 0                    Azuay            CAMILO PONCE ENRIQUEZ    9766    7638
# 1                      NaN              EL CARMEN DE PIJILI    2445    2149
# 2                      NaN                            Total   12211    9787
# 3                      NaN                        CHORDELEG    3241    3546
# 4                      NaN                         LA UNION     867    1029
# 5                      NaN            LUIS GALARZA ORELLANA     661     833
# 6                      NaN                        PRINCIPAL     597     734
# 7                      NaN             SAN MARTIN DE PUZHIO     455     614
# 8                      NaN                            Total    5821    6756
# 9                      NaN                            BAÑOS    7868    8983
# 10                     NaN                          CHAUCHA     617     680
# ...

# %%
# A la vez que podemso buscar un dato en especifico
tabla1.loc[tabla1.Provincia=='Loja']
# Out:
#     Provincia               Nombre del Canton Nombre de la Parroquia Hombre  \
# 600      Loja  CALVAS                                     CARIAMANGA  10402
#
#      Mujer  Total
# 600  10899  21301
